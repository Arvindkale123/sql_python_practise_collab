# %% [markdown]
# <a href="https://colab.research.google.com/github/Arvindkale123/sql_python_practise_collab/blob/main/Copy_of_Day_1__Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PYTHON**

# %% [markdown]
# ## 1. Write a program in Python to check whether an integer is Armstrong number or not.
#
# **What is Armstrong Number?**
#
# It is a number which is equal to the sum of cube of its digits.
# For eg: 153, 370 etc.
# Lets see it practically by calculating it,
#
# Suppose I am taking 153 for an example
#
# First calculate the cube of its each digits
#
#   1^3 = (1 * 1 * 1) = 1
#
#   5^3 = (5 * 5 * 5) = 125
#
#   3^3= (3 * 3 * 3) = 27
#
# Now add the cube
#
# 1+125+27 = 153
#
# It means 153 is an Armstrong Number.

# %%
number = int(input('Enter any positive number : '))

def check_armstrong(num):
    if num in range(1,10):
        return True

    order = len(str(num))
    sum = 0
    original = num
    while num>0:
        digit = num % 10
        sum += digit ** order
        num = num // 10
    if sum == original:
        return True
    return False

if check_armstrong(number):
    print('number is armsrong')
else:
    print('number is not armsrong')
# Out:
# Enter any positive number : 153
# number is armsrong

# %% [markdown]
# ## 2. Write a program in Python to print the fibonacci series using recursive method.
#
#
# **What is Fibonacci Series?**
#
# A Fibonacci series is a series in which next number is a sum of previous two numbers.
#
#
#
# For example : 0, 1, 1, 2, 3, 5, 8 ……
#
# In Fibonacci Series, first number starts with 0 and second is with 1 and then its grow like,
#
# 0
#
# 1
#
#
#
# 0 + 1 = 1
#
# 1 + 1 = 2
#
# 1 + 2 = 3
#
# 2 + 3 = 5 and
#
# so on…
#
# How our program will behave?
# Its Logic is different from Fibonacci series program in c using iterative method.
#
# Here we have a function named fibonacci() which will take a input and then return element. Each time it will call itself to calculate the elements of the series.
#
# Like if someone given 6 as a input then our program should return,
#
# 0, 1, 1, 2, 3, 5

# %%
# Write Your Code Here


num = int(input("Enter any number :"))
n1, n2 = 0, 1
sum = 0
if num <= 0:
    print('Please enter number greater than 0')
else:
    for i in range(0, num):
        print(sum, end=" ")
        n1 = n2
        n2 = sum
        sum = n1 + n2

print('completed..')
# Out:
# Enter any number :6
# 0 1 1 2 3 5 completed..

# %% [markdown]
# # **SQL**

# %% [markdown]
# You have to use PandaSQL to write sql queries on dataframes.
#
# Please Go through the blog to know more about Pandasql: [Pandasql -The Best Way to Run SQL Queries in Python](https://www.analyticsvidhya.com/blog/2021/07/pandasql-best-way-to-run-sql-queries-and-codes-in-jupyter-notebook-using-python/)
#
# Install PandaSQL: !pip install pandasql
#
#
#
# ```
# from pandasql import sqldf
#
# mysql = lambda q: sqldf(q, globals())
#
# mysql('''select * from table''')
# ```

# %% [markdown]
# ## 3. From the following dataframes, write a SQL query to find the information on each salesperson of ABC Company. Return name, city, country and state of each salesperson.

# %% [markdown]
# **Create Dataframe 1: salespersons**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Create Dataframe 2: address**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Installing Pandasql
# !pip install pandasql
# Importing Libraries
import pandas as pd
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())

# Creating DataFrames
salespersons=pd.DataFrame([['1', 'Green', 'Wright'],['2', 'Jones', 'Collins'],['3', 'Bryant', 'Davis']],columns=["salesperson_id","first_name","last_name"])
address=pd.DataFrame([['1', '2', 'Los Angeles','California', 'USA'],['2', '3', 'Denver', 'Colorado','USA'],['3', '4', 'Atlanta', 'Georgia','USA']],columns=["address_id","salesperson_id","city","state","country"])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandasql in /usr/local/lib/python3.7/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.21.6)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.4.40)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.8.1)

# %%
# Write Your Code Here
query = '''
SELECT  first_name,last_name,city,state 
FROM salespersons
 LEFT JOIN
address
on salespersons.salesperson_id = address.salesperson_id
order by last_name;
'''





mysql(query)
# Out:
#   first_name last_name         city       state
# 0      Jones   Collins  Los Angeles  California
# 1     Bryant     Davis       Denver    Colorado
# 2      Green    Wright         None        None

# %% [markdown]
# ## 4. A salesperson is a person whose job is to sell products or services.
# ## From the following dataframe, write a SQL query to find the top 10 salesperson that have made highest sale. Return their names and total sale amount.

# %% [markdown]
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Install SQlite
# !pip install db-sqlite3

# Importing Libraries
import pandas as pd
import sqlite3

# Connection to DataBase
conn = sqlite3.connect('test1_database') 
c = conn.cursor()

# Create table
c.execute('''
          DROP TABLE IF EXISTS sales;''')
c.execute('''CREATE TABLE sales (
[TRANSACTION_ID] INTEGER PRIMARY KEY NOT NULL,
[SALESMAN_ID]   INTEGER NOT NULL,
[SALE_AMOUNT]  decimal);''')
          
# Insert data into table          
c.execute('''INSERT INTO sales VALUES(501,18,5200.00),(502,50,5566.00),(503,38,8400.00),(504,43,8400.00),(505,11,9000.00);''') 
c.execute('''INSERT INTO sales VALUES (506,42,5900.00),(507,13,7000.00),(508,33,6000.00),(509,41,8200.00),(510,11,4500.00);''') 
c.execute('''INSERT INTO sales VALUES (511,51,10000.00),(512,29,9500.00),(513,59,6500.00),(514,38,7800.00),(515,58,9800.00);''') 
c.execute('''INSERT INTO sales VALUES (516,60,12000.00),(517,58,13900.00),(518,23,12200.00),(519,34,5480.00),(520,35,8129.00);''') 
c.execute('''INSERT INTO sales VALUES (521,49,9323.00),(522,46,8200.00),(523,47,9990.00),(524,42,14000.00),(525,44,7890.00);''') 
c.execute('''INSERT INTO sales VALUES (526,47,5990.00),(527,21,7770.00),(528,57,6645.00),(529,56,5125.00),(530,25,10990.00);''') 
c.execute('''INSERT INTO sales VALUES (531,21,12600.00),(532,41,5514.00),(533,17,15600.00),(534,44,15000.00),(535,12,17550.00);''') 
c.execute('''INSERT INTO sales VALUES (536,55,13000.00),(537,58,16800.00),(538,25,19900.00),(539,57,9990.00),(540,28,8900.00);''') 
c.execute('''INSERT INTO sales VALUES (541,44,10200.00),(542,57,18000.00),(543,34,16200.00),(544,36,19998.00),(545,30,13500.00);''') 
c.execute('''INSERT INTO sales VALUES (546,37,15520.00),(547,36,20000.00),(548,20,19800.00),(549,22,18530.00),(550,19,12523.00);''') 
c.execute('''INSERT INTO sales VALUES (551,46,9885.00),(552,22,7100.00),(553,54,17500.00),(554,19,19600.00),(555,24,17500.00);''') 
c.execute('''INSERT INTO sales VALUES (556,38,7926.00),(557,49,7548.00),(558,15,9778.00),(559,56,19330.00),(560,24,14400.00);''') 
c.execute('''INSERT INTO sales VALUES (561,18,16700.00),(562,54,6420.00),(563,31,18720.00),(564,21,17220.00),(565,48,18880.00); ''') 
c.execute('''INSERT INTO sales VALUES (566,33,8882.00),(567,44,19550.00),(568,22,14440.00),(569,53,19500.00),(570,30,5300.00);''') 
c.execute('''INSERT INTO sales VALUES (571,30,10823.00),(572,35,13300.00),(573,35,19100.00),(574,18,17525.00),(575,60,8995.00);''') 
c.execute('''INSERT INTO sales VALUES (576,53,9990.00),(577,21,7660.00),(578,27,18990.00),(579,11,18200.00),(580,30,12338.00);''') 
c.execute('''INSERT INTO sales VALUES (581,37,11000.00),(582,27,11980.00),(583,18,12628.00),(584,52,11265.00),(585,53,19990.00);''') 
c.execute('''INSERT INTO sales VALUES (586,27,8125.00),(587,25,7128.00),(588,57,6760.00),(589,19,5985.00),(590,52,17641.00);''') 
c.execute('''INSERT INTO sales VALUES (591,53,11225.00),(592,22,12200.00),(593,59,16520.00),(594,35,19990.00),(595,42,19741.00);''') 
c.execute('''INSERT INTO sales VALUES (596,19,15000.00),(597,57,19625.00),(598,53,9825.00),(599,24,16745.00),(600,12,14900.00);''')  

# Create table
c.execute('''
          DROP TABLE IF EXISTS salesman;''')

# Insert data into table
c.execute('''CREATE TABLE salesman (
SALESMAN_ID INTEGER PRIMARY KEY NOT NULL,
SALESMAN_NAME  varchar);''')

c.execute('''INSERT INTO salesman VALUES(11	,'Jonathan Goodwin');''')
c.execute('''INSERT INTO salesman VALUES(12	,'Adam Hughes');''')
c.execute('''INSERT INTO salesman VALUES(13	,'Mark Davenport       ');''')
c.execute('''INSERT INTO salesman VALUES(14	,'Jamie Shelley        ');''')
c.execute('''INSERT INTO salesman VALUES(15	,'Ethan Birkenhead     ');''')
c.execute('''INSERT INTO salesman VALUES(16	,'Liam Alton           ');''')
c.execute('''INSERT INTO salesman VALUES(17	,'Josh Day             ');''')
c.execute('''INSERT INTO salesman VALUES(18	,'Sean Mann            ');''')
c.execute('''INSERT INTO salesman VALUES(19	,'Evan Blake           ');''')
c.execute('''INSERT INTO salesman VALUES(20	,'Rhys Emsworth        ');''')
c.execute('''INSERT INTO salesman VALUES(21	,'Kian Wordsworth      ');''')
c.execute('''INSERT INTO salesman VALUES(22	,'Frederick Kelsey     ');''')
c.execute('''INSERT INTO salesman VALUES(23	,'Noah Turner          ');''')
c.execute('''INSERT INTO salesman VALUES(24	,'Callum Bing          ');''')
c.execute('''INSERT INTO salesman VALUES(25	,'Harri Wilberforce    ');''')
c.execute('''INSERT INTO salesman VALUES(26	,'Gabriel Gibson       ');''')
c.execute('''INSERT INTO salesman VALUES(27	,'Richard York         ');''')
c.execute('''INSERT INTO salesman VALUES(28	,'Tobias Stratford     ');''')
c.execute('''INSERT INTO salesman VALUES(29	,'Will Kirby           ');''')
c.execute('''INSERT INTO salesman VALUES(30	,'Bradley Wright       ');''')
c.execute('''INSERT INTO salesman VALUES(31	,'Eli Willoughby       ');''')
c.execute('''INSERT INTO salesman VALUES(32	,'Patrick Riley        ');''')
c.execute('''INSERT INTO salesman VALUES(33	,'Kieran Freeman       ');''')
c.execute('''INSERT INTO salesman VALUES(34	,'Toby Scott           ');''')
c.execute('''INSERT INTO salesman VALUES(35	,'Elliot Clapham       ');''')
c.execute('''INSERT INTO salesman VALUES(36	,'Lewis Moss           ');''')
c.execute('''INSERT INTO salesman VALUES(37	,'Joshua Atterton      ');''')
c.execute('''INSERT INTO salesman VALUES(38	,'Jonathan Reynolds    ');''')
c.execute('''INSERT INTO salesman VALUES(39	,'David Hill           ');''')
c.execute('''INSERT INTO salesman VALUES(40	,'Aidan Yeardley       ');''')
c.execute('''INSERT INTO salesman VALUES(41	,'Dan Astley           ');''')
c.execute('''INSERT INTO salesman VALUES(42	,'Finlay Dalton        ');''')
c.execute('''INSERT INTO salesman VALUES(43	,'Toby Rodney          ');''')
c.execute('''INSERT INTO salesman VALUES(44	,'Ollie Wheatley       ');''')
c.execute('''INSERT INTO salesman VALUES(45	,'Sean Spalding        ');''')
c.execute('''INSERT INTO salesman VALUES(46	,'Jason Wilson         ');''')
c.execute('''INSERT INTO salesman VALUES(47	,'Christopher Wentworth');''')
c.execute('''INSERT INTO salesman VALUES(48	,'Cameron Ansley       ');''')
c.execute('''INSERT INTO salesman VALUES(49	,'Henry Porter         ');''')
c.execute('''INSERT INTO salesman VALUES(50	,'Ezra Winterbourne    ');''')
c.execute('''INSERT INTO salesman VALUES(51	,'Rufus Fleming        ');''')
c.execute('''INSERT INTO salesman VALUES(52	,'Wallace Dempsey      ');''')
c.execute('''INSERT INTO salesman VALUES(53	,'Dan McKee            ');''')
c.execute('''INSERT INTO salesman VALUES(54	,'Marion Caldwell      ');''')
c.execute('''INSERT INTO salesman VALUES(55	,'Morris Phillips      ');''')
c.execute('''INSERT INTO salesman VALUES(56	,'Chester Chandler     ');''')
c.execute('''INSERT INTO salesman VALUES(57	,'Cleveland Klein      ');''')
c.execute('''INSERT INTO salesman VALUES(58	,'Hubert Bean          ');''')
c.execute('''INSERT INTO salesman VALUES(59	,'Cleveland Hart       ');''')
c.execute('''INSERT INTO salesman VALUES(60	,'Marion Gregory       ');''')

conn.commit()

# Get DataFrame
conn = sqlite3.connect('test1_database') 
sales = pd.read_sql_query ('''SELECT * FROM sales''',conn)
salesman=pd.read_sql_query ('''SELECT * FROM salesman''',conn)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: db-sqlite3 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: db in /usr/local/lib/python3.7/dist-packages (from db-sqlite3) (0.1.1)
# Requirement already satisfied: antiorm in /usr/local/lib/python3.7/dist-packages (from db->db-sqlite3) (1.2.1)

# %%
# Write Your Code

salesman_table='''
SELECT * 
FROM salesman
LIMIT 5;'''
mysql(salesman_table)
# Out:
#    SALESMAN_ID          SALESMAN_NAME
# 0           11       Jonathan Goodwin
# 1           12            Adam Hughes
# 2           13  Mark Davenport
# 3           14  Jamie Shelley
# 4           15  Ethan Birkenhead

# %%
sales_table='''
SELECT * 
FROM sales
LIMIT 5;'''

mysql(sales_table)
# Out:
#    TRANSACTION_ID  SALESMAN_ID  SALE_AMOUNT
# 0             501           18         5200
# 1             502           50         5566
# 2             503           38         8400
# 3             504           43         8400
# 4             505           11         9000

# %%
output='''
SELECT SALESMAN_NAME , SUM(SALE_AMOUNT) as TOTAL_AMOUNT
FROM salesman
INNER JOIN
sales
ON salesman.SALESMAN_ID=sales.SALESMAN_ID
GROUP BY SALESMAN_NAME
ORDER BY TOTAL_AMOUNT DESC
LIMIT 10;

'''

mysql(output)
# Out:
#            SALESMAN_NAME  TOTAL_AMOUNT
# 0  Dan McKee                     70530
# 1  Cleveland Klein               61020
# 2  Elliot Clapham                60519
# 3  Evan Blake                    53108
# 4  Ollie Wheatley                52640
# 5  Frederick Kelsey              52270
# 6  Sean Mann                     52053
# 7  Callum Bing                   48645
# 8  Kian Wordsworth               45250
# 9  Bradley Wright                41961

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 5. What is the value of the function (x − 1) (x − 2)^2 at its maxima?
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![q5.jpeg](data:image/jpeg;base64,...)Upload your answer here.

# %% [markdown]
# ![q6.jpeg](data:image/jpeg;base64,...)Upload your answer here.

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 7. How do you choose a machine learning algorithm for a problem statement?
# The Very first step would be to create a Problem Statement from the problem given by the Business.
#
# Whenever we start working on any Machine Learning project, we first need to understand what the problem is
#
# WE should be able to understand what type of problem we want to solve and it mainly depends on how you set the problem statement
#
# Setting a problem statement includes the input and output of the business problem We want to solve.
#
#
# Once the problem statement is defined, We should be able to identify which algorithm we should choose among below types:
#
# Any Classification Algorithm
# Any Clustering Algorithm
# Any Regression Algorithm
# Any Recommendation Algorithm
#
# -->When to use Classification Algorithms:
# For example, your problem statement is a question to classify something(ie Is this good or bad?) or when your goal is to predict discrete values, e.g. {1,0}, {True, False}, {Spam, No Spam}
#
# In that case we use classification Algorithems for example
#
# 1.Logistice Regression.
#
# 2.Decision Tree
#
# 3.Random Forest
#
# 4.XG Boost Classifier.
#
# 5.k_nearest Neighbour
#
# 6.Neive Baise Classifier.
#
# 7.Support vector Machine.
#
# -->When to use Regression Algorithms:
# For example, you want to compute some continuous value as compared to Classification where the output is categoric. So whenever you are told to predict some future value of a process which is currently running, you can go with Regression Algorithm.
#
# Here you deal with numbers and there might be questions about How much or how many or how long or Impact of something on something else in your problem statement, in such cases you should go with Regression.
#
# Examples of Rgression Algorithms are
#
# 1.Logistic Regression
#
# 2.Decision Tree Regressor
#
# 3.XG Boost Regressor.
#
# 4.Ada Boost Regressor
#
# 5.K_nearest Neighbour.
#
# -->When to use Clustering Algorithms:
# For example, there is a large group of users and you want to divide them into particular groups based on some common attributes. But the key part is when the groups to be divided into are unknown beforehand. So you should go with Clustering Algorithm when there are not known attributes beforehand.
#
# If there are questions like how is this organized or grouping something or concentrating on particular groups etc in your problem statement then you should go with Clustering.
#
# Examples of Unsupervised machine learning algorithem
#
# 1. Kmeans Clusturing.
#
# 2.Hairarchical Clustering.
#
# When to use Recommendation Algorithms:
# For example, when you want to determine what kind of theme a user would like in future based on the user’s past behavior. Like as Collaborative filtering(for example, User like you also liked kind of things)
#
# So when there are some questions like what the user should do next or suggest something to the user or top choices of particular users etc in your problem statement then you should go with Recommendation.
#
# Example of Recommendation Algorithm:
#
# Collaborative filtering Algorithm
# Logistic Regression Algorithm
# Polynomial Regression Algorithm etc
#
#
#
#
# ----> Now we have seen when to use which type of algothem now there is a question that for examples
# There are many classification algorithem by appliying that we could predict decrete number or a classification problem
# now the questition arrises that where to use which type of classification algothem.
#
# 1.Where to use which kind of classification algorithem is completly depend on our dataset
#
# 2.We have to use some python libraries i.e Matplotlib,Seaborn to visualize the data points in our dataset by which we can find the relation between each features.
#
# 3.With the help of data visualization libraries we can estimate that which algorithem will gives us optimum result
#
# ---> For example we draw a pairplot with the help o seaborn library so we can visualize the relation between all the features and we can estimate that which algorithem should we use.
#
# ---> Logistic Regression
# When we visualize data points and observe that there is a linear relation between the feature then we can use logistic regression for classification.
#
# that will fit a perfect straight line and classify classes .
#
# Now if there is no linear relation and the data point is overlapping so we can go to the K_nearest Neighbour classifier
# as these algorithem measures a euclidian distance
#
# Also We have other non linear algothem like Decision Tree, Random Forest , Support Vector Machine .
#
#
# We need to visualize dataset and estimate which algothem is optimum because If we apply 2-3 algorithem and out data having for example 1 million records .
#
# It becomes time consuming also Having High Computational Cost.

# %% [markdown]
# The Very first step would be to create a Problem Statement from the problem given by the Business.

# %% [markdown]
# ## 8. What is Semi- Supervised Learning and why is it so important?

# %% [markdown]
# The biggest difference between supervised and unsupervised machine learning and semisupervised machine learning is this:
#
# -->Supervised machine learning algorithms are trained on datasets that include labels added by a machine learning engineer or data scientist that guide the algorithm to understand which features are important to the problem at hand.
#
# -->Unsupervised machine learning algorithms, on the other hand, are trained on unlabeled data and must determine feature importance on their own based on inherent patterns in the data.
#
#
# -->Semi-supervised learning algorithms are trained on a combination of labeled and unlabeled data. This is useful for a few reasons. First, the process of labeling massive amounts of data for supervised learning is often prohibitively time-consuming and expensive.
#
# -->Too much labeling can impose human biases on the model. That means including lots of unlabeled data during the training process actually tends to improve the accuracy of the final model while reducing the time and cost spent building it.
#
# For that reason, semi-supervised learning is a win-win for use cases like webpage classification, speech recognition, or even for genetic sequencing. In all of these cases, data scientists can access large volumes of unlabeled data, but the process of actually assigning supervision information to all of it would be an insurmountable task.
#
# Using classification as an example, let’s compare how these three approaches work in practice:
#
# Supervised classification: The algorithm learns to assign labels to types of webpages based on the labels that were inputted by a human during the training process.
# Unsupervised clustering: The algorithm looks at inherent similarities between webpages to place them into groups.
# Semi-supervised classification: Labeled data is used to help identify that there are specific groups of webpage types present in the data and what they might be. The algorithm is then trained on unlabeled data to define the boundaries of those webpage types and may even identify new types of webpages that were unspecified in the existing human-inputted labels.
